# %% [markdown]
# <a href="https://colab.research.google.com/github/josemariagarcia143/digitalizacion/blob/main/Heron_area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cálculo del área de un triángulo
# Usando la fórmula de Herón, calculamos el área de cualquier triángulo conociendo la longitud de sus tres lados. Debes escribir un programa que te pida los tres lados y que calcule el área.
#
#
# > Cálculo del semiperímetro: $s = \frac{a+b+c}{2}$
#
# > Cálculo del área: $área = \sqrt{s(s-a)(s-b)(s-c)}$

# %%
#Pedimos el valor entero de cada uno de los lados
ladoA = int(input('Escribe la longitud de un lado: '))
ladoB = int(input('Escribe la longitud de otro lado: '))
ladoC = int(input('Escribe la longitud del último lado: '))

#Cálculo del semiperímetro
semi = (ladoA + ladoB + ladoC)/2
#Cálculo del área
area = (semi * (semi - ladoA) * (semi - ladoB) * (semi - ladoC))**(1/2)
#Imprimimos el resultado
print('El área del triángulo es',area)

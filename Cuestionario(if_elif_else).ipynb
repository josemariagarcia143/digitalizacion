# %% [markdown]
# <a href="https://colab.research.google.com/github/josemariagarcia143/digitalizacion/blob/main/Cuestionario(if_elif_else).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 3: Créate un Cuestionario [Programar Juegos Arcade con Python y Pygame](http://programarcadegames.com/index.php)
#
#
# #Descripción
# Estas son las características que debe tener tu cuestionario:
#
#
# 1.   Créalo con cinco o más preguntas. Puedes preguntar cosas que requieran
# *   un número como respuesta (por ejemplo; ¿Cuánto es 1+1?)
# *   texto (Por ejemplo; ¿Cuál es el apellido de Harry Potter?)
# *   una selección (¿Cuál de estas opciones son las correctas A, B, o C?)
#
# 2.   Si permites que el usuario introduzca respuestas no numéricas, piensa y cubre las distintas formas en que podría contestar. Por ejemplo, si la respuesta es “a”, sería aceptable también “A”? Échale un vistazo a la Sección 3.6 para que recuerdes cómo conseguir esto.
#
# 3. Debes permitir que el usuario sepa que ha acertado con la respuesta correcta. Imprime un mensaje basado en esa respuesta.
# 4. Debes llevar la cuenta del número de respuestas acertadas.
# 5. Al final del programa, deberás mostrar el porcentaje de respuestas contestadas correctamente por el usuario.
#
# #Ejemplo de ejecución
#
# ```
# ¡A jugar!
#
# ¿De cuántos libros consta la serie de Harry Potter? 7
# Correcto!
#
# ¿Cuánto es 3*(2-1)? 3
# Correcto!
#
# ¿Cuánto es 3*2-1? 5
# Correcto!
#
# ¿Quién canta Black Horse and the Cherry Tree?
# 1. Kelly Clarkson
# 2. K.T. Tunstall
# 3. Hillary Duff
# 4. Bon Jovi
# ? 2
# Correcto!
#
# ¿Qué personaje aparece en el billete de un dólar?
# 1. George Washington
# 2. Abraham Lincoln
# 3. John Adams
# 4. Thomas Jefferson
# ? 2
# No.
#
# Mis felicitaciones, has conseguido 4 respuestas correctas!
# Eso es una puntuación del 80 por ciento.
# ```

# %% [markdown]
# # Crea un celda de código debajo y escribe allí tu programa

# %%
print("¡A jugar!\n1. ¿Cuánto es 2 * 5 * (4 - 3)?\n")
r1 = int(input("Respuesta: "))
if r1 == 7:
  print("¡Correcto!")
  c1 = 1
else:
  print("¡Incorrecto!")
print("\n2. ¿Cuánto es 1 + 1?\n\n1. No sé\n2. 7\n3. Soy de letras\n4. 2")
r2 = int(input("Respuesta: "))
if r2 == 4:
  print("¡Correcto!")
  c2 = 1
else:
  print("¡Incorrecto!")
print("\n3. ¿Cuáles han sucedido de verdad de estos eventos históricos? Selecciona 2.\n\n1. La Mordida del '87\n2. La Gran Guerra\n3. La Caída del Imperio Romano\n4. El Juicio Final")
r3_1 = int(input("Respuesta 1: "))
r3_2 = int(input("Respuesta 2: "))
if r3_1 == 2:
  if r3_2 == 3:
    print("¡Correcto!")
    c3 = 1
elif r3_1 == 3:
  if r3_2 == 2:
    print("¡Correcto!")
    c3 = 1
else:
  print("¡Incorrecto!")
print("\n4. En un año bisiesto, ¿cuántos días hay en un mes máximo?")
r4 = int(input("Respuesta: "))
if r4 == 31:
  print("¡Correcto!")
  c4 = 1
else:
  print("¡Incorrecto!")
print("\n5. ¿Cuántos hoyos hay en un polo?\n\n1. 357\n2. 3\n3. 0'235\n4. 29")
r5 = int(input("Respuesta: "))
if r5 == 2:
  print("¡Correcto! ¡\"un polo\" tiene 3 hoyos!")
  c5 = 1
else:
  print("¡Incorrecto! ¿Es que no sabes contar?")
c = c1 + c2 + c3 + c4 + c5
porc = (5*c)/100
print("\n¡SE ACABÓ!\n\nHas acertado",c,"preguntas; ¡un",porc,"por ciento de respuestas correctas!")
if c == 0:
  print("¡No te desanimes! ¡Reinténtalo!")
elif c == 5:
  print("¡Te lo has pasado! ¡Felicidades! No tienes porqué repetirlo.")
else:
  print("¿Quieres una puntuación perfecta? ¡Pues inténtalo de nuevo!")
# Out:
# ¡A jugar!
# 1. ¿Cuánto es 2 * 5 * (4 - 3)?
#
# Respuesta: 7
# ¡Correcto!
#
# 2. ¿Cuánto es 1 + 1?
#
# 1. No sé
# 2. 7
# 3. Soy de letras
# 4. 2
# Respuesta: 4
# ¡Correcto!
#
# 3. ¿Cuáles han sucedido de verdad de estos eventos históricos? Selecciona 2.
#
# 1. La Mordida del '87
# 2. La Gran Guerra
# 3. La Caída del Imperio Romano
# 4. El Juicio Final
# Respuesta 1: 2
# Respuesta 2: 3
# ¡Correcto!
#
# 4. En un año bisiesto, ¿cuántos días hay en un mes máximo?
# Respuesta: 31
# ¡Correcto!
#
# 5. ¿Cuántos hoyos hay en un polo?
#
# 1. 357
# 2. 3
# 3. 0'235
# 4. 29
# Respuesta: 2
# ¡Correcto! ¡"un polo" tiene 3 hoyos!
#
# ¡SE ACABÓ!
#
# Has acertado 5 preguntas; ¡un 0.25 por ciento de respuestas correctas!
# ¡Te lo has pasado! ¡Felicidades! No tienes porqué repetirlo.
